# %%
# summary statistics of time series
from pandas import read_csv
# Out:
# /home/kranthidr/.virtualenvs/tml-lab/lib64/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/kranthidr/.virtualenvs/tml-lab/lib64/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
series = read_csv('dataset.csv', header=None, index_col=0, parse_dates=True, squeeze=True)
print(series.describe())
# Out:
# count     69.000000
# mean     500.478261
# std       73.901685
# min      344.000000
# 25%      458.000000
# 50%      492.000000
# 75%      538.000000
# max      662.000000
# Name: 1, dtype: float64

# %%
series.head(1)
# Out:
# 0
# 1885-01-01    356
# Name: 1, dtype: int64

# %%
series.tail(1)
# Out:
# 0
# 1953-01-01    538
# Name: 1, dtype: int64

# %%
# line plot of time series
from matplotlib import pyplot

# %%
series.plot()
pyplot.show()

# %%
# density plots of time series
pyplot.figure(1)
pyplot.subplot(211)
series.hist()
pyplot.subplot(212)
series.plot(kind='kde')
pyplot.show()
# Out:
# /home/kranthidr/.virtualenvs/tml-lab/lib64/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# boxplots of time series
from pandas import Grouper, DataFrame

# %%
groups = series.groupby(Grouper(freq='10YS'))
decades = DataFrame()

# %%
for name, group in groups:
    print("name = {}, group = {}".format(name, group.values.mean()))
    if len(group.values) is 10:
        decades[name.year] = group.values
# Out:
# name = 1885-01-01 00:00:00, group = 398.6
# name = 1895-01-01 00:00:00, group = 459.8
# name = 1905-01-01 00:00:00, group = 514.0
# name = 1915-01-01 00:00:00, group = 516.9
# name = 1925-01-01 00:00:00, group = 468.6
# name = 1935-01-01 00:00:00, group = 566.2
# name = 1945-01-01 00:00:00, group = 588.0
# name = 1955-01-01 00:00:00, group = nan
# /home/kranthidr/.virtualenvs/tml-lab/lib/python3.5/site-packages/ipykernel_launcher.py:2: RuntimeWarning: Mean of empty slice.
#
# /home/kranthidr/.virtualenvs/tml-lab/lib/python3.5/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
list(groups)[-1]
# Out:
# (Timestamp('1955-01-01 00:00:00'), Series([], Name: 1, dtype: int64))

# %%
list(groups)[-2]
# Out:
# (Timestamp('1945-01-01 00:00:00'), 0
#  1945-01-01    606
#  1946-01-01    632
#  1947-01-01    617
#  1948-01-01    613
#  1949-01-01    598
#  1950-01-01    575
#  1951-01-01    564
#  1952-01-01    549
#  1953-01-01    538
#  Name: 1, dtype: int64)

# %%
decades.boxplot()
pyplot.show()
