// %%
spark
// Out:
// Waiting for a Spark session to start...
// Spark application_1533622723243_21712: Some(http://gw02.itversity.com:4051)

// %%
spark.sparkContext.getConf.getAll.foreach(x=>if(x._2.contains("/proxy/")){println(x._2)})
// Out:
// Waiting for a Spark session to start...
// http://rm01.itversity.com:19288/proxy/application_1533622723243_21712

// %%
import scala.collection.JavaConversions._

// %%
val os_name = System.getProperty("os.name")
val hdfs_home = "/user/" + System.getProperty("user.home").split("/")(2)
// Out:
// os_name = Linux
// hdfs_home = /user/kranthidr
// /user/kranthidr

// %%
val path = hdfs_home+"/dataSets/wikidump-02-sept-2018.xml"
// Out:
// path = /user/kranthidr/dataSets/wikidump-02-sept-2018.xml
// /user/kranthidr/dataSets/wikidump-02-sept-2018.xml

// %%
import com.cloudera.datascience.lsa._
import com.cloudera.datascience.lsa.AssembleDocumentTermMatrix
import com.cloudera.datascience.lsa.LSAQueryEngine
import com.cloudera.datascience.lsa.RunLSA._

// %%
import breeze.linalg.{DenseMatrix => BDenseMatrix, SparseVector => BSparseVector}

import org.apache.spark.mllib.linalg.{Matrices, Matrix, SingularValueDecomposition, Vectors, Vector => MLLibVector}
import org.apache.spark.ml.linalg.{Vector => MLVector}
import org.apache.spark.mllib.linalg.distributed.RowMatrix
import org.apache.spark.serializer.KryoSerializer
import org.apache.spark.sql.{Dataset, SparkSession}

import scala.collection.Map
import scala.collection.mutable.ArrayBuffer
// Out:
// import breeze.linalg.{DenseMatrix=>BDenseMatrix, SparseVector=>BSparseVector}
// import org.apache.spark.mllib.linalg.{Matrices, Matrix, SingularValueDecomposition, Vectors, Vector=>MLLibVector}
// import org.apache.spark.ml.linalg.{Vector=>MLVector}

// %%
val k =  100
val numTerms = 20000
// Out:
// k = 100
// numTerms = 20000
// 20000

// %%
val assembleMatrix = new AssembleDocumentTermMatrix(spark)
import assembleMatrix._
// Out:
// assembleMatrix = com.cloudera.datascience.lsa.AssembleDocumentTermMatrix@36dfb57f
// com.cloudera.datascience.lsa.AssembleDocumentTermMatrix@36dfb57f

// %%
val docTexts: Dataset[(String, String)] = parseWikipediaDump(path)
// Out:
// docTexts = [_1: string, _2: string]
// [_1: string, _2: string]

// %%
docTexts.cache()
// Out:
// lastException: Throwable = null
// [_1: string, _2: string]

// %%
val docTexts1 = docTexts.sample(false, 0.001) //50 Docs we get approx
// Out:
// docTexts1 = [_1: string, _2: string]
// [_1: string, _2: string]

// %%
docTexts1.count()
// Out:
// 5656

// %%
val (docTermMatrix, termIds, docIds, termIdfs) = documentTermMatrix(docTexts1, "stopwords.txt", numTerms)
// Out:
// docTermMatrix = [title: string, tfidfVec: vector]
// termIds = Array(also, new, first, one, year, reference, use, two, include, school, time, make, may, name, team, state, university, work, station, play, world, link, become, class, city, win, see, national, external, film, defaultsort, united, bear, take, american, part, release, john, season, cross, group, member, can, later, family, south, know, three, list, circle, march, award, area, people, game, october, second, war, end, september, follow, album, district, november, many, january, high, lead, county, place, road, april, club, call, song, company, history, august, december, show, states, college, write, june, begin, league, note, july, number, house, music, record, north, series, day, e...
// [also, new, first, one, year, reference, use, two, include, school, time, make, may, name, team, state, university, work, station, play, world, link, become, class, city, win, see, national, external, film, defaultsort, united, bear, take, american, part, release, john, season, cross, group, member, can, later, family, south, know, three, list, circle, march, award, area, people, game, october, second, war, end, september, follow, album, district, november, many, january, high, lead, county, place, road, april, club, call, song, company, history, august, december, show, states, college, write, june, begin, league, note, july, number, house, music, record, north, series, day, early, york, since, town, february, form, life, church, man, give, find, center, international, party, well, service, west, market, leave, serve, result, the, move, hold, park, title, british, will, base, start, live, however, best, general, die, feature, open, hospital, force, nagar, book, point, art, come, four, race, run, player, london, several, return, former, village, east, english, system, government, football, home, order, championship, set, building, woman, build, country, band, say, back, line, gate, child, receive, support, century, bus, river, age, final, population, air, law, design, public, study, now, central, change, official, bgcolor, report, total, local, like, major, ret, cup, track, publish, provide, island, single, last, located, language, career, corporation, field, death, appear, main, event, community, create, street, president, office, join, date, continue, position, son, head, student, william, round, around, old, another, present, version, third, german, produce, railway, long, program, top, division, king, museum, site, hall, role, election, due, love, director, david, original, references, remain, get, stage, act, power, chart, james, episode, side, board, george, french, development, still, match, along, radio, within, star, tour, white, black, score, department, website, great, european, establish, project, small, region, research, association, society, land, union, water, near, video, species, lose, young, sign, press, large, way, council, perform, complete, allow, story, father, develop, western, free, issue, five, canada, vote, character, army, source, file, describe, police, kempegowda, peak, represent, court, northern, among, although, example, just, late, help, attack, artist, right, education, england, political, america, kill, performance, million, close, business, plan, thomas, robert, television, different, production, often, australia, period, paul, term, royal, next, consider, together, human, case, finish, control, professional, san, six, pass, fall, officer, block, various, summer, even, mark, good, turn, week, meet, battle, much, accord, marry, information, lake, france, contain, found, special, route, indian, southern, word, rock, female, cover, refer, ship, michael, coach, military, richard, winner, collection, direct, movement, style, cause, peter, level, science, minister, car, germany, short, debut, standard, institute, month, daughter, every, medal, brother, india, without, common, sell, mountain, align, fight, unit, wife, section, layout, offer, province, bring, mount, mary, announce, tell, festival, california, network, body, charles, mother, type, japan, fire, australian, reach, competition, current, review, store, guitar, academy, plant, engine, send, location, eastern, grow, though, social, rank, goal, popular, break, appoint, operation, involve, centre, train, appearance, operate, committee, individual, tournament, night, average, red, leader, range, green, master, washington, elect, process, organization, author, conference, russian, news, important, never, need, defeat, decide, originally, writer, face, theatre, magazine, compete, edition, commission, little, draw, replace, sport, per, chief, records, kingdom, currently, friend, enter, malleshwaram, increase, van, post, label, try, grand, smith, b ...

// %%
docTexts.unpersist()
// Out:
// [_1: string, _2: string]

// %%
docTermMatrix.cache()
// Out:
// [title: string, tfidfVec: vector]

// %%
 val vecRdd = docTermMatrix.select("tfidfVec").rdd.map { row =>
      Vectors.fromML(row.getAs[MLVector]("tfidfVec"))
}
// Out:
// vecRdd = MapPartitionsRDD[83] at map at <console>:53
// MapPartitionsRDD[83] at map at <console>:53

// %%
docTermMatrix.unpersist()
// Out:
// [title: string, tfidfVec: vector]

// %%
vecRdd.cache()
// Out:
// MapPartitionsRDD[83] at map at <console>:53

// %%
    val mat = new RowMatrix(vecRdd)
// Out:
// mat = org.apache.spark.mllib.linalg.distributed.RowMatrix@1346ee39
// %%
    val topConceptDocs = topDocsInTopConcepts(svd, 10, 10, docIds)
// Out:
// topConceptDocs = ArrayBuffer(ArraySeq((List of BMTC routes,0.999959129345759), (Mercat cross,0.003192017277100499), (List of hospitals in the Republic of Ireland,0.003056784190751809), (Occupy movement in the United States,0.002128467523640035), (Dartmouth Steam Railway,0.0021086211923507995), (List of terrorist incidents in 2002,0.0019628276865620935), (Attapur,0.0017069713656653657), (History of Knott's Berry Farm,0.0015942864887940557), (List of convicts on the First Fleet,0.0015451302135670935), (List of New York City Subway stations in Brooklyn,0.0012331631865231789)), ArraySeq((List of BMTC routes,3.502801412206937E-5), (Joonas Myyrä,0.0), (Willmar, MN µSA,0.0), (Missio Immaculatae,0.0), (Aethopyga mystacalis,0.0), (Asanuma Inejirō,0.0), (Ayios Vlasios,...
// ArrayBuffer(ArraySeq((List of BMTC routes,0.999959129345759), (Mercat cross,0.003192017277100499), (List of hospitals in the Republic of Ireland,0.003056784190751809), (Occupy movement in the United States,0.002128467523640035), (Dartmouth Steam Railway,0.0021086211923507995), (List of terrorist incidents in 2002,0.0019628276865620935), (Attapur,0.0017069713656653657), (History of Knott's Berry Farm,0.0015942864887940557), (List of convicts on the First Fleet,0.0015451302135670935), (List of New York City Subway stations in Brooklyn,0.0012331631865231789)), ArraySeq((List of BMTC routes,3.502801412206937E-5), (Joonas Myyrä,0.0), (Willmar, MN µSA,0.0), (Missio Immaculatae,0.0), (Aethopyga mystacalis,0.0), (Asanuma Inejirō,0.0), (Ayios Vlasios,0.0), (Loren Babcock,0.0), (MTR M-Train EMU,0.0), (Loya Paktya,0.0)), ArraySeq((List of BMTC routes,8.580718062225994E-4), (List of minor planets: 216001–217000,3.613106354945373E-4), (List of hospitals in the Republic of Ireland,3.9551803639559214E-6), (On-deck,9.278588664113302E-7), (Meanings of minor planet names: 98001–99000,5.387153166036253E-7), (University Hospital Summerville,5.209149372788776E-7), (Koraon,2.235286196975751E-7), (Mania, Dildarnagar,1.706318594148386E-7), (Huangxing Road station,1.653805075228176E-7), (Internet Corporation for Assigned Names and Numbers,1.244649575741504E-7)), ArraySeq((List of United Kingdom locations: Mar-Md,0.0014157483109847365), (List of minor planets: 216001–217000,4.779716224140116E-4), (List of BMTC routes,4.758273782786479E-4), (Joonas Myyrä,0.0), (Willmar, MN µSA,0.0), (Missio Immaculatae,0.0), (Aethopyga mystacalis,0.0), (Asanuma Inejirō,0.0), (Ayios Vlasios,0.0), (Loren Babcock,0.0)), ArraySeq((List of convicts on the First Fleet,0.9414316007170167), (Occupy movement in the United States,0.09932342218706786), (Japanese general election, 2017,0.09244969930732912), (Samuel Pepys,0.08526500179451804), (ATP-binding cassette transporter,0.06138924711966076), (2012 Roger Federer tennis season,0.05481841973995255), (American and British English spelling differences,0.050551559379677806), (Reasons of the Supreme Court of Canada by Chief Justice McLachlin,0.041951406220061396), (United Front for the Liberation of Oppressed Races,0.04033465442916926), (List of Rainbow (TV series) episodes,0.03823015998693158)), ArraySeq((List of convicts on the First Fleet,0.1557927617226861), (1987 Formula One World Championship,0.005246041050682095), (2009 Superbike World Championship,0.0038593882529478598), (Judd (engine),0.0036566383650058726), (2002 European Touring Car Championship,0.00172502896883397), (List of European Aquatics Championships medalists in swimming (women),0.0014327547991859451), (List of United Kingdom locations: Mar-Md,0.001108601496061348), (Lady Penrhyn (1783 ship),8.675383488484836E-4), (List of minor planets: 216001–217000,7.637872239276702E-4), (List of BMTC routes,6.999111308764982E-4)), ArraySeq((Japanese general election, 2017,0.1325606651871081), (List of convicts on the First Fleet,0.09714262746979938), (1987 Formula One World Championship,0.009492646752259333), (Judd (engine),0.007803028658999509), (2009 Superbike World Championship,0.0034722800835506025), (2002 European Touring Car Championship,0.0029804760758793286), (Abe Schwartz,0.001869670868089491), (List of United Kingdom locations: Mar-Md,0.0016840376840440918), (List of BMTC routes,0.0010365655363458735), (List of minor planets: 216001–217000,9.122548286911217E-4)), ArraySeq((Global Tag League,0.34134031968105644), (List of convicts on the First Fleet,0.20342126527948898), (Japanese general election, 2017,0.18635206805833102), (1987 Formula One World Championship,0.013371966022620675), (2009 Superbike World Championship,0.011447211920618401), (Judd (engine),0.00566074022001395), (List of United Kingdom locations: Mar-Md,0.004451466535891112), (2002 European Touring Car Championship,0.0039044194964662536), (List of BMTC routes,0.002151731735577522), (List of minor planet ...

// %%
    for ((terms, docs) <- topConceptTerms.zip(topConceptDocs)) {
      println("Concept terms: " + terms.map(_._1).mkString(", "))
      println("Concept docs: " + docs.map(_._1).mkString(", "))
      println()
    }
// Out:
// Concept terms: nagar, circle, kempegowda, cross, gate, bus, malleshwaram, palya, market, station
// Concept docs: List of BMTC routes, Mercat cross, List of hospitals in the Republic of Ireland, Occupy movement in the United States, Dartmouth Steam Railway, List of terrorist incidents in 2002, Attapur, History of Knott's Berry Farm, List of convicts on the First Fleet, List of New York City Subway stations in Brooklyn
//
// Concept terms: nagar, kempegowda, circle, malleshwaram, palya, gate, shivajinagar, yeshwantpur, layout, sirsi
// Concept docs: List of BMTC routes, Joonas Myyrä, Willmar, MN µSA, Missio Immaculatae, Aethopyga mystacalis, Asanuma Inejirō, Ayios Vlasios, Loren Babcock, MTR M-Train EMU, Loya Paktya
//
// Concept terms: nagar, circle, kempegowda, malleshwaram, palya, bus, bgcolor, layout, hospital, corporation
// Concept docs: List of BMTC routes, List of minor planets: 216001–217000, List of hospitals in the Republic of Ireland, On-deck, Meanings of minor planet names: 98001–99000, University Hospital Summerville, Koraon, Mania, Dildarnagar, Huangxing Road station, Internet Corporation for Assigned Names and Numbers
//
// Concept terms: vcard, adr, nagar, org, bgcolor, circle, kempegowda, gate, malleshwaram, palya
// Concept docs: List of United Kingdom locations: Mar-Md, List of minor planets: 216001–217000, List of BMTC routes, Joonas Myyrä, Willmar, MN µSA, Missio Immaculatae, Aethopyga mystacalis, Asanuma Inejirō, Ayios Vlasios, Loren Babcock
//
// Concept terms: convict, london, steal, sentence, bailey, scarborough, charlotte, exeter, john, commute
// Concept docs: List of convicts on the First Fleet, Occupy movement in the United States, Japanese general election, 2017, Samuel Pepys, ATP-binding cassette transporter, 2012 Roger Federer tennis season, American and British English spelling differences, Reasons of the Supreme Court of Canada by Chief Justice McLachlin, United Front for the Liberation of Oppressed Races, List of Rainbow (TV series) episodes
//
// Concept terms: convict, london, steal, sentence, bailey, scarborough, charlotte, exeter, commute, penrhyn
// Concept docs: List of convicts on the First Fleet, 1987 Formula One World Championship, 2009 Superbike World Championship, Judd (engine), 2002 European Touring Car Championship, List of European Aquatics Championships medalists in swimming (women), List of United Kingdom locations: Mar-Md, Lady Penrhyn (1783 ship), List of minor planets: 216001–217000, List of BMTC routes
//
// Concept terms: shinzō, abe, shimbun, convict, steal, london, yomiuri, nhk, sentence, oct
// Concept docs: Japanese general election, 2017, List of convicts on the First Fleet, 1987 Formula One World Championship, Judd (engine), 2009 Superbike World Championship, 2002 European Touring Car Championship, Abe Schwartz, List of United Kingdom locations: Mar-Md, List of BMTC routes, List of minor planets: 216001–217000
//
// Concept terms: sugiura, yone, shinzō, marufuji, abe, saito, taniguchi, convict, nakajima, shiozaki
// Concept docs: Global Tag League, List of convicts on the First Fleet, Japanese general election, 2017, 1987 Formula One World Championship, 2009 Superbike World Championship, Judd (engine), List of United Kingdom locations: Mar-Md, 2002 European Touring Car Championship, List of BMTC routes, List of minor planets: 216001–217000
//
// Concept terms: transporter, exporter, abc, nbd, atp, protein, binding, substrate, domain, tmd
// Concept docs: ATP-binding cassette transporter, 2012 Roger Federer tennis season, Occupy movement in the United States, Lorentz force, Robotics, United Front for the Liberation of Oppressed Races, Peace & Prosperity, Elastin-like polypeptides, Florida–Tennessee football rivalry, Nucleotide excision repair
//
// Concept terms: transporter, scc, exporter, abc, nbd, protein, binding, atp, substrate, domain
// Concept docs: ATP-binding cassette transporter, Reasons of the Supreme Court of Canada by Chief Justice McLachlin, List of convicts on the First Fleet, Japanese general election, 2017, Global Tag League, Amino acid transporter, Nucleotide excision repair, Elastin-like polypeptides, BAR domain, 1987 Formula One World Championship

// %%
    val queryEngine = new LSAQueryEngine(svd, termIds, docIds, termIdfs)
// Out:
// queryEngine = com.cloudera.datascience.lsa.LSAQueryEngine@2d4c4c25
// com.cloudera.datascience.lsa.LSAQueryEngine@2d4c4c25

// %%
    queryEngine.printTopTermsForTerm("algorithm")
// Out:
// (algorithm,0.9999999999999996), (fundamentally,0.9538345102693473), (propagate,0.9505437087708588), (digit,0.9201524010684025), (method,0.8969983021151294), (precision,0.8546089493159822), (zero,0.8501539662034177), (extended,0.8122851267306269), (corresponding,0.8037959481075951), (operand,0.7939031488284806)

// %%
    queryEngine.printTopTermsForTerm("kempegowda")
// Out:
// (kempegowda,0.9999999999999998), (sirsi,0.9999999950716311), (talkies,0.9999999950716311), (huskur,0.9999999950716311), (palya,0.999999995071631), (mayohall,0.999999995071631), (ulsoor,0.999999995071631), (puram,0.999999995071631), (hebbal,0.999999995071631), (shivananda,0.999999995071631)
// lastException: Throwable = null

// %%
    queryEngine.printTopTermsForTerm("malleshwaram")
// Out:
// (sirsi,0.9999999999999999), (talkies,0.9999999999999999), (huskur,0.9999999999999999), (palya,0.9999999999999998), (mayohall,0.9999999999999998), (ulsoor,0.9999999999999998), (puram,0.9999999999999998), (hebbal,0.9999999999999998), (shivananda,0.9999999999999998), (kottigepalya,0.9999999999999998)

// %%
    queryEngine.printTopDocsForTerm("fir")
// Out:
// (Nucleotide excision repair,10.710033149931384), (Anion gap,7.84620536785346), (Pinophyta,7.487784309750477), (Elastin-like polypeptides,5.093414920174936), (Castanopsis,3.9750662652860713), (Women in journalism,3.3042198665154268), (History of paper,3.2653481483386155), (Bass–Serre theory,3.259487376006185), (Vireo,2.778234438413666), (Blue cone monochromacy,2.675827851264626)
// lastException: Throwable = null

// %%
    queryEngine.printTopDocsForTerm("graph")
// Out:
// (Bass–Serre theory,259.02987839396195), (Davis Cup,25.7209623643185), (Richard Brauer,17.914899691135826), (Pinophyta,14.806024638106456), (Bullet graph,10.325770938727308), (2012–13 in Spanish football,9.954872034593345), (Revival Centres International,8.881976921309867), (XDI,8.328890143997462), (2018–19 Danish 2nd Divisions,8.32873112913863), (The Trouble with Physics,8.29508374129109)

// %%
    queryEngine.printTopDocsForDoc("BAR domain")
// Out:
// (BAR domain,0.9999999999999998), (Amino acid transporter,0.9205773602633391), (TMC8,0.9119419268739763), (ATP-binding cassette transporter,0.8946194434694467), (C1QTNF5,0.8757624265740518), (Viperin,0.8716276664686162), (Argininosuccinate synthase,0.8658697344826495), (CHCHD2,0.8620463975217801), (SH3BGRL3,0.8573977626641787), (MPDZ,0.8438025466099988)

// %%
    queryEngine.printTopDocsForDoc("List of BMTC routes")
// Out:
// (List of BMTC routes,1.0000000000000004), (Cross that bridge,0.9134903449403701), (Internet Corporation for Assigned Names and Numbers,0.8464025003110763), (Raja Nagar,0.7818170958040493), (On-deck,0.6798722913522431), (List of progestogen esters,0.6776934956016234), (Mercat cross,0.673682545526864), (List of hospitals in the Republic of Ireland,0.6653245508488901), (Mania, Dildarnagar,0.6547977141247985), (Rawatpur,0.6421826009698794)

// %%
    queryEngine.printTopDocsForDoc("ATP-binding cassette transporter")
// Out:
// (ATP-binding cassette transporter,0.9999999999999993), (Amino acid transporter,0.9892641423840888), (Gold nanoparticles in drug delivery,0.8960418601948735), (BAR domain,0.8946194434694467), (Macromphaliinae,0.8325449758473372), (TMC8,0.8285080560692341), (Peter D. Mitchell,0.7631180065493101), (Argininosuccinate synthase,0.7566217510128299), (Viperin,0.7497435406349588), (C1QTNF5,0.7395854285959019)

// %%
    queryEngine.printTopDocsForTermQuery(Seq("nagar", "circle"))
// Out:
// (List of BMTC routes,76521.96234689369), (Mercat cross,232.92649356851106), (List of hospitals in the Republic of Ireland,229.07562958166176), (Apostolic Vicariate of Northern Germany,169.47205248407943), (Attapur,124.27923173497874), (SpellForce: The Order of Dawn,81.28045229856237), (List of terrorist incidents in 2002,72.57781363588069), (History of Knott's Berry Farm,67.40714481963052), (Krishnadevaraya College of Dental Sciences and Hospital,64.72745063670381), (A63 road,57.91104513384207)
